# %%
# importing the packages needed

import pandas as pd
import numpy as np

# %%
# let's format the notebook
pd.set_option("display.max_columns", None)
pd.options.mode.copy_on_write = True

# %%
# loading the dataset
dataframe = pd.read_csv("data/fifa21_raw_data.csv")

dataframe.sample(4)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19964\2268519056.py:2: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv("data/fifa21_raw_data.csv")
#            ID           Name                  LongName  \
# 3882   230248  Antonaldo Vaz  Antonaldo Luiz Vaz Stein
# 12947  212978   P. Banggaard         Patrick Banggaard
# 8099   225455      V. Dávila             Víctor Dávila
# 11931  211702      M. Endres               Marc Endres
#
#                                                photoUrl  \
# 3882   https://cdn.sofifa.com/players/230/248/21_60.png
# 12947  https://cdn.sofifa.com/players/212/978/21_60.png
# 8099   https://cdn.sofifa.com/players/225/455/21_60.png
# 11931  https://cdn.sofifa.com/players/211/702/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 3882   http://sofifa.com/player/230248/antonaldo-luiz...      Brazil   20
# ...

# %%
dataframe.shape
# Out:
# (18979, 77)

# %%
dataframe.info()

# %% [markdown]
# #### Cleaning the columns

# %%
# let's clean the club column to remove the \n

dataframe.Club = dataframe.Club.str.strip()

dataframe.Club.unique()
